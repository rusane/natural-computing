# %% [markdown]
# # Base Learner Runs (with Refit)
#
# This notebook runs the base learners $n$ times and saves the output to a CSV file separately for each base learner. Use `sfm` model to refit data from Features Importance experiment

# %% [markdown]
# ## Imports

# %%
# sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# custom modules
from tadpole import Tadpole
from classifier import Classifier
from main import run, get_params

# %% [markdown]
# ## Data Loading

# %%
# %%time
tp = Tadpole()
# Out:
# CPU times: user 10.8 s, sys: 684 ms, total: 11.5 s
# Wall time: 11.6 s

# %%
n_runs = 30

# %%
params_dtc = get_params('refit_dtc')
params_svc = get_params('refit_svc')
params_lra = get_params('refit_lra')
params_ann = get_params('refit_ann')

# %%
# output (best params) filenames
dtc_out = './results/refit_dtc.csv'
svc_out = './results/refit_svc.csv'
lra_out = './results/refit_lra.csv'
ann_out = './results/refit_ann.csv'

# %% [markdown]
# ## Base Learners: Parameters from Grid Search (with Refit) Experiment
# ### DTC

# %%
dtc = Classifier(DecisionTreeClassifier(), params_dtc)
run(dtc, tp, n_runs=n_runs, output=dtc_out, refit=True)
# Out:
# 100%|██████████| 30/30 [00:27<00:00,  1.09it/s]
#     BCA_train  BCA_test  mAUC_train  mAUC_test
# 0    0.770184  0.781214    0.903366   0.897843
# 1    0.756290  0.702932    0.880984   0.835268
# 2    0.780038  0.789929    0.919506   0.914871
# 3    0.868548  0.854121    0.948348   0.937404
# 4    0.821759  0.836124    0.898156   0.899625
# 5    0.839349  0.820261    0.933687   0.933336
# 6    0.765043  0.746326    0.882224   0.872584
# 7    0.837753  0.826647    0.941427   0.930423
# 8    0.823965  0.799522    0.920120   0.902128
# 9    0.653356  0.657582    0.812052   0.803972
# 10   0.855198  0.839254    0.950362   0.937564
# 11   0.891797  0.878033    0.962581   0.955345
# 12   0.880581  0.805987    0.961341   0.946404
# 13   0.839777  0.818552    0.941593   0.933531
# 14   0.821759  0.836124    0.912072   0.907861
# 15   0.841002  0.813650    0.942480   0.928528
# 16   0.728645  0.702603    0.870674   0.855523
# 17   0.911970  0.868518    0.963741   0.955201
# 18   0.789604  0.812892    0.919114   0.921430
# 19   0.816442  0.829613    0.926408   0.936634
# 20   0.825661  0.820513    0.900508   0.875115
# 21   0.892038  0.905837    0.958210   0.958943
# 22   0.866205  0.863491    0.940440   0.942810
# 23   0.888182  0.850085    0.965921   0.952129
# 24   0.863530  0.860384    0.947963   0.953726
# 25   0.818145  0.804072    0.928507   0.913253
# 26   0.768831  0.733803    0.906484   0.897738
# 27   0.883815  0.843988    0.956062   0.935533
# 28   0.892630  0.903468    0.963441   0.972422
# 29   0.755954  0.785313    0.901473   0.911907

# %% [markdown]
# ### SVC

# %%
svc = Classifier(SVC(probability=True), params_svc)
run(svc, tp, n_runs=n_runs, output=svc_out, refit=True)
# Out:
# 100%|██████████| 30/30 [00:29<00:00,  1.01it/s]
#     BCA_train  BCA_test  mAUC_train  mAUC_test
# 0    0.894129  0.914467    0.965114   0.975795
# 1    0.901193  0.878116    0.965839   0.945041
# 2    0.893593  0.906353    0.969517   0.964537
# 3    0.897815  0.890144    0.971304   0.967459
# 4    0.899355  0.902110    0.961355   0.960760
# 5    0.897120  0.907855    0.963393   0.970623
# 6    0.889361  0.915415    0.960355   0.964843
# 7    0.896101  0.894035    0.964035   0.963639
# 8    0.895545  0.901162    0.960721   0.965742
# 9    0.893948  0.923736    0.957993   0.974002
# 10   0.892146  0.904499    0.968770   0.975881
# 11   0.901620  0.888372    0.970165   0.960449
# 12   0.907793  0.848848    0.969446   0.951930
# 13   0.893742  0.917948    0.969052   0.979989
# 14   0.897491  0.894859    0.965138   0.967239
# 15   0.899818  0.885551    0.972272   0.956546
# 16   0.898283  0.895335    0.962381   0.955664
# 17   0.905729  0.878322    0.969562   0.966715
# 18   0.904499  0.873440    0.970704   0.961370
# 19   0.896976  0.909916    0.969628   0.974024
# 20   0.895823  0.905982    0.971012   0.970756
# 21   0.892182  0.917124    0.963911   0.974015
# 22   0.898835  0.902707    0.960854   0.968307
# 23   0.898835  0.886292    0.962858   0.957019
# 24   0.900004  0.885035    0.969944   0.974413
# 25   0.895545  0.892388    0.963916   0.965295
# 26   0.892944  0.917948    0.962950   0.972225
# 27   0.904797  0.860732    0.967457   0.954249
# 28   0.894484  0.906661    0.966855   0.974563
# 29   0.895488  0.897516    0.963591   0.966807

# %% [markdown]
# ### LRA

# %%
lra = Classifier(LogisticRegression(), params_lra)
run(lra, tp, n_runs=n_runs, output=lra_out, refit=True)
# Out:
# 100%|██████████| 30/30 [00:25<00:00,  1.16it/s]
#     BCA_train  BCA_test  mAUC_train  mAUC_test
# 0    0.890082  0.911274    0.971318   0.975510
# 1    0.902892  0.881535    0.973871   0.960823
# 2    0.897939  0.901225    0.971825   0.971041
# 3    0.895400  0.898773    0.972934   0.969762
# 4    0.897166  0.906126    0.971740   0.971757
# 5    0.895194  0.899906    0.970409   0.976761
# 6    0.890735  0.918834    0.970678   0.977504
# 7    0.894360  0.884602    0.971346   0.971045
# 8    0.892981  0.904354    0.972163   0.972193
# 9    0.887595  0.918607    0.969520   0.981639
# 10   0.891775  0.906208    0.970867   0.975500
# 11   0.897919  0.891339    0.972736   0.965411
# 12   0.905148  0.858199    0.973704   0.960718
# 13   0.876453  0.909483    0.967787   0.979637
# 14   0.891308  0.903551    0.972619   0.968395
# 15   0.899818  0.883841    0.973886   0.962830
# 16   0.895586  0.892287    0.973517   0.964952
# 17   0.900178  0.878322    0.972556   0.970363
# 18   0.903644  0.872328    0.973985   0.961397
# 19   0.891735  0.899659    0.970922   0.974519
# 20   0.893114  0.899597    0.972125   0.970765
# 21   0.888053  0.910287    0.970308   0.975317
# 22   0.895509  0.899288    0.970733   0.976535
# 23   0.901121  0.888146    0.973754   0.963312
# 24   0.903798  0.884972    0.970114   0.973623
# 25   0.898593  0.897516    0.971417   0.973739
# 26   0.895158  0.914529    0.969618   0.980112
# 27   0.905394  0.865860    0.974199   0.962953
# 28   0.896235  0.905549    0.970359   0.976732
# 29   0.885459  0.881617    0.971740   0.972120

# %% [markdown]
# ### ANN

# %%
ann = Classifier(MLPClassifier(), params_ann)
run(ann, tp, n_runs=n_runs, output=ann_out, refit=True)
# Out:
# 100%|██████████| 30/30 [01:29<00:00,  2.98s/it]
#     BCA_train  BCA_test  mAUC_train  mAUC_test
# 0    0.874103  0.918564    0.970819   0.974253
# 1    0.888088  0.859475    0.974319   0.961093
# 2    0.874917  0.901533    0.971661   0.971159
# 3    0.896465  0.868022    0.973110   0.969395
# 4    0.864501  0.862277    0.972147   0.971373
# 5    0.892022  0.891892    0.970865   0.975895
# 6    0.877728  0.909482    0.970785   0.977638
# 7    0.886044  0.898133    0.972044   0.970831
# 8    0.890652  0.878361    0.971641   0.971179
# 9    0.886250  0.914384    0.969514   0.982466
# 10   0.871380  0.862874    0.971075   0.975603
# 11   0.885364  0.849609    0.973184   0.964036
# 12   0.892794  0.819889    0.974548   0.961490
# 13   0.886415  0.926495    0.969922   0.980278
# 14   0.890869  0.873994    0.972903   0.968386
# 15   0.897449  0.877682    0.974136   0.962152
# 16   0.866483  0.848355    0.973415   0.963606
# 17   0.899627  0.868744    0.972680   0.970107
# 18   0.899622  0.864089    0.974610   0.960155
# 19   0.880977  0.887568    0.971259   0.975256
# 20   0.881682  0.878135    0.972071   0.971388
# 21   0.886621  0.902274    0.970790   0.977358
# 22   0.884489  0.876632    0.970487   0.975160
# 23   0.888520  0.856509    0.973843   0.962725
# 24   0.891991  0.854140    0.970849   0.974796
# 25   0.885879  0.899678    0.971277   0.973152
# 26   0.885467  0.903983    0.970115   0.979827
# 27   0.901517  0.872698    0.974130   0.962117
# 28   0.889087  0.897372    0.970716   0.976265
# 29   0.876822  0.896486    0.969567   0.969861
